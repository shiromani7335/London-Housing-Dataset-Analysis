# %% [markdown]
# # London Housing Dataset

# %% [markdown]
# This dataset primarily centered around the housing market of London. it contains a lot of additional relevant data.
# * Monthly average house prices
# * Yearlynumber of house sold
# * Monthly number of crimes committed
#
# The data used here is from year 1995 to 2019 of each different area
#
# This data is avaliable as a CSV file. downloded from kaggle.
#
# We will analyze this data using Pandas DataFrame.
#
# Here, random sets of questions are given for which we have to find correct results.
#
# This project is for beginners and for those who want to know how we analyze big data with Python.

# %% [markdown]
# The commands that we used in this project :
#
# * import pandas as pd -- To import Pandas library
# * pd.read_csv - To import the CSV file in Jupyter notebook
# * df.count() - It counts the no. of non-null values of each column.
# * df.isnull().sum() - It detects the missing values from the dataframe.
# * import seaborn as sns - To import the Seaborn library.
# * import matplotlib.pyplot as plt - To import the Matplotlib library.
# * sns.heatmap(df.isnull()) - It will show the all columns & missing values in them in heat map form.
# * plt.show() - To show the plot.
# * df.dtypes - To show the datatype of each column.
# * pd.to_datetime(df.Date_Time_Col) - Converts the data-type of Date-Time Column into datetime[ns] datatype.
# * df.Time_Col.dt.year - Creating a new column with only year values
# * df.Time_Col.dt.month - Creating a new column with only month values.
# * df.insert( index , ‘new_column_name’, new_column_values) - To insert a New column at a particular position with values in it.
# * df.drop(['Col_name'] , axis=1 , inplace = True) - To drop a column from the dataframe permanently.
# * df.groupby(‘Col_name’) - To form groups of all unique values of the column.
# * df[df.Col_1 = = ‘Element1’] - Filtering – We are accessing all records with Element1 only of Col_1.
# * df.groupby(‘Col_1’)[‘Col_2’] .mean( ) - To create groups - Two Keys – Apply on Col_2 grouped by Col_1.

# %%
import pandas as pd

# %%
data=pd.read_csv(r"H:\Jupyter lab programm\Data analytics project\Project 5 London Housing Data\5. London Housing Data.csv")
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# # Exploration of our data

# %%
# 1.
# df.count()
# df.isnull().sum()

# %%
data.count()       #It shows the total no. of non-null values in each column. It can be applied on a single column as well as on the whole dataframe.
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
data.average_price.count()    # count of non-null values for a perticular column
# Out:
# 13549

# %%
data.isnull().sum()      # count of null values
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %% [markdown]
#  2. If we want to see the null values and correlation in the form of Heatmap using seaborn lib for visualization purpose

# %%
 # import seaborn as sbn
 # import matplotlib.pyplot as plt
 # sbn.heatmap(df.isnull())
 # plt.show()

# %%
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
sbn.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
sbn.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 1) Convert the Datatype of 'Date' column to Date-Time format.

# %%
# data.dtype
# data.date= pd.to_datetime(dataframe_name.Column_name)
# or
# data.date= pd.to_datetime(dataframe_name.Column_name)

# %%
data.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data.dtypes           # for knowing dtype of dataset
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
data.date= pd.to_datetime(data.date)

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %% [markdown]
# # 2.1) Add a new column ''year'' in the dataframe, which contains years only.

# %%
# data['New_Column_Name']= df.Date_Column.dt.year

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN

# %%
data['year']= data.date.dt.year     # syntax to add a new column in the last position of the dataframe
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 0               NaN  1995
# 1               NaN  1995
# ...

# %%
# data['month']= data.date.dt.month               # similarly for month 
# data

# %% [markdown]
# # 2.2) Add a new column ''month'' as 2nd column in the dataframe, which contains month only.

# %%
# df.insert(index, 'new_column_name', new_column_values)
# data.insert (1,'month',data.date.dt.month)

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995

# %%
data.insert(1,'month',data.date.dt.month)          # syntax to add a new column at perticular position of the dataframe (her, 1 is the index after which 
                                                   # we want to add new column)

# %%
 data.head()
# Out:
#         date  month            area  average_price       code  houses_sold  \
# 0 1995-01-01      1  city of london          91449  E09000001         17.0
# 1 1995-02-01      2  city of london          82203  E09000001          7.0
# 2 1995-03-01      3  city of london          79121  E09000001         14.0
# 3 1995-04-01      4  city of london          77101  E09000001          7.0
# 4 1995-05-01      5  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %% [markdown]
# # 3) Remove the columns 'year' and 'month' from the dataframe.

# %%
# removal of columns from dataframe
# df.drop(['Column1','Column2'], axis=1, inplace=True)

# %%
data.head()
# Out:
#         date  month            area  average_price       code  houses_sold  \
# 0 1995-01-01      1  city of london          91449  E09000001         17.0
# 1 1995-02-01      2  city of london          82203  E09000001          7.0
# 2 1995-03-01      3  city of london          79121  E09000001         14.0
# 3 1995-04-01      4  city of london          77101  E09000001          7.0
# 4 1995-05-01      5  city of london          84409  E09000001         10.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995
# 2           NaN  1995
# 3           NaN  1995
# 4           NaN  1995

# %%
data.drop(['year','month'], axis=1,inplace=True)

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# ...

# %% [markdown]
# # 4) Show all the records where 'No. of Crimes' is 0. And, how many such records are there ?

# %%
# data[data.no_of_crimes==0]
# len(data[data.no_of_crimes==0])

# %%
data[data.no_of_crimes==0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
len(data[data.no_of_crimes==0])        # No. of  records where 'No. of Crimes' is 0
# Out:
# 104

# %% [markdown]
# # 5) What is the maximum & minimum 'average_price' per year in england ?

# %%
# df1=data[data.area=='england']
# df1.groupby('year').average_price.max()/min()/mean()

# %%
# data.head(2)

# %% [markdown]
# now first of all we have to create a new column 'year'

# %%
data['year']=data.date.dt.year

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  year
# 0           NaN  1995
# 1           NaN  1995

# %%
df1=data[data.area=='england']
df1
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# ...          ...      ...            ...        ...          ...
# 13544 2019-09-01  england         249942  E92000001      64605.0
# 13545 2019-10-01  england         249376  E92000001      68677.0
# 13546 2019-11-01  england         248515  E92000001      67814.0
# 13547 2019-12-01  england         250410  E92000001          NaN
# 13548 2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  year
# 13248           NaN  1995
# 13249           NaN  1995
# 13250           NaN  1995
# 13251           NaN  1995
# 13252           NaN  1995
# ...

# %%
data.groupby('year').average_price.min().sort_values(ascending=True)
# Out:
# year
# 1996     40722
# 1995     41688
# 1997     42353
# 1998     43510
# 1999     43969
# 2000     47604
# 2001     49045
# 2002     54746
# 2003     67520
# 2004     88520
# 2005    110454
# 2013    112008
# 2012    113011
# 2014    114531
# 2011    115328
# 2009    117079
# 2015    117156
# 2010    119688
# 2008    120275
# 2016    121085
# 2006    121124
# 2017    121858
# 2018    124038
# 2019    124567
# 2020    126592
# 2007    131175
# Name: average_price, dtype: int64

# %%
data.groupby('year').average_price.max().sort_values(ascending=True)
# Out:
# year
# 1995     200722
# 1996     223197
# 1997     265112
# 1998     277600
# 1999     354241
# 2000     397353
# 2001     451028
# 2003     488704
# 2002     497538
# 2005     555847
# 2004     559286
# 2006     644541
# 2009     782459
# 2007     830950
# 2008     832753
# 2010     884674
# 2011     959520
# 2012    1077366
# 2020    1178166
# 2013    1217729
# 2019    1294113
# 2015    1353679
# 2016    1357231
# 2014    1365050
# 2017    1412255
# 2018    1463378
# Name: average_price, dtype: int64

# %% [markdown]
# # 6) What is the Maximum & Minimum No. of Crimes recorded per area ?

# %%
# data.groupby('area').no_of_crimes.max()
# data.groupby('area').no_of_crimes.min().sort_values(ascending=True)

# %%
data.groupby('area').no_of_crimes.max().sort_values(ascending= True)
# Out:
# area
# city of london              10.0
# kingston upon thames      1379.0
# sutton                    1425.0
# richmond upon thames      1551.0
# merton                    1623.0
# harrow                    1763.0
# bexley                    1914.0
# havering                  1956.0
# barking and dagenham      2049.0
# redbridge                 2560.0
# bromley                   2637.0
# hammersmith and fulham    2645.0
# kensington and chelsea    2778.0
# enfield                   2798.0
# lewisham                  2813.0
# hounslow                  2817.0
# hillingdon                2819.0
# greenwich                 2853.0
# barnet                    2893.0
# brent                     2937.0
# waltham forest            2941.0
# wandsworth                3051.0
# haringey                  3199.0
# croydon                   3263.0
# tower hamlets             3316.0
# islington                 3384.0
# ealing                    3401.0
# hackney                   3466.0
# ...

# %%
#data.head()

# %%
data.groupby('area').no_of_crimes.min().sort_values(ascending=False)
# Out:
# area
# westminster               3504.0
# lambeth                   2381.0
# southwark                 2267.0
# newham                    2130.0
# camden                    2079.0
# croydon                   2031.0
# islington                 1871.0
# ealing                    1871.0
# hackney                   1870.0
# brent                     1850.0
# barnet                    1703.0
# lewisham                  1675.0
# tower hamlets             1646.0
# enfield                   1635.0
# wandsworth                1582.0
# waltham forest            1575.0
# haringey                  1536.0
# hounslow                  1529.0
# greenwich                 1513.0
# redbridge                 1487.0
# hillingdon                1445.0
# bromley                   1441.0
# kensington and chelsea    1347.0
# hammersmith and fulham    1323.0
# barking and dagenham      1217.0
# havering                  1130.0
# harrow                     937.0
# bexley                     860.0
# ...

# %% [markdown]
# # 7) Show the total count of records of each area, where average price is less than 100000.

# %%
# data[data.average_prices<100000].area.value_counts()

# %%
data[data.average_price<100000].area.value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...
